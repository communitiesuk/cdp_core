# %%
# %run ./define_tables

# %%
spark.sql(f"DROP TABLE IF EXISTS {bronze_table} PURGE")
spark.sql(f"DROP TABLE IF EXISTS {silver_table} PURGE")
spark.sql(f"DROP TABLE IF EXISTS {gold_table} PURGE")
spark.sql(f"DROP TABLE IF EXISTS {bronze_london_authorities_table} PURGE")
spark.sql(f"DROP TABLE IF EXISTS {silver_london_authorities_table} PURGE")

dbutils.fs.rm(checkpoint_path, True)
